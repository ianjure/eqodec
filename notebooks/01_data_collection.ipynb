# %% [markdown]
# ### **Notebook Objective**
#
# This notebook outlines the data acquisition strategy.

# %% [markdown]
# ### **Data Collection**
#
# We utilize the following dataset:
#
# **Vimeo-90K (Septuplet):** For training our autoencoder to learn temporal and spatial redundancies.
#
# ---
#
# To train the models, we require a large-scale dataset containing high-quality video sequences. We select the **Vimeo-90K Septuplet dataset**. This dataset consists of 91,701 7-frame sequences with fixed resolution (448 × 256). It is widely regarded as the standard benchmark for video restoration and compression tasks.
#
# The temporal consistency of the septuplets allows our model to learn motion compensation effectively, a critical component for reducing bitrate while maintaining visual fidelity.
#
# **Manual Download Instructions:**
# To replicate our training environment, we acquire the dataset as follows:
#
# 1. **Source:** [Vimeo-90K Dataset](http://toflow.csail.mit.edu/)
# 2. **Selection:** Download the *"Septuplet"* version (approx. 82GB uncompressed).
